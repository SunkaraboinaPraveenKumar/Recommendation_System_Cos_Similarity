# %%
# !pip install nltk scikit-learn numpy pandas -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
df=pd.read_csv('movies.csv')

# %%
df.shape
# Out:
# (4803, 24)

# %%
df.head(2)
# Out:
#    index  ...        director
# 0      0  ...   James Cameron
# 1      1  ...  Gore Verbinski
#
# [2 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
#  15  spoken_languages      4803 non-null   object
#  16  status                4803 non-null   object
#  17  tagline               3959 non-null   object
#  18  title                 4803 non-null   object
#  19  vote_average          4803 non-null   float64
#  20  vote_count            4803 non-null   int64
#  21  cast                  4760 non-null   object
#  22  crew                  4803 non-null   object
#  23  director              4773 non-null   object
# dtypes: float64(3), int64(5), object(16)
# memory usage: 900.7+ KB

# %%
df.isnull().sum()
# Out:
# index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %%
required_columns = ['genres', 'keywords', 'title', 'overview']
df = df[required_columns]

# %%
df.shape
# Out:
# (4803, 4)

# %%
df.head()
# Out:
#                                      genres  ...                                           overview
# 0  Action Adventure Fantasy Science Fiction  ...  In the 22nd century, a paraplegic Marine is di...
# 1                  Adventure Fantasy Action  ...  Captain Barbossa, long believed to be dead, ha...
# 2                    Action Adventure Crime  ...  A cryptic message from Bond’s past sends him o...
# 3               Action Crime Drama Thriller  ...  Following the death of District Attorney Harve...
# 4          Action Adventure Science Fiction  ...  John Carter is a war-weary, former military ca...
#
# [5 rows x 4 columns]

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4387 entries, 0 to 4386
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4387 non-null   object
#  1   keywords  4387 non-null   object
#  2   title     4387 non-null   object
#  3   overview  4387 non-null   object
# dtypes: object(4)
# memory usage: 137.2+ KB

# %%
df.shape
# Out:
# (4387, 4)

# %%
df['combined']=df['genres']+' '+df['keywords']+' '+df['overview']

# %%
df.head()
# Out:
#                                      genres  ...                                           combined
# 0  Action Adventure Fantasy Science Fiction  ...  Action Adventure Fantasy Science Fiction cultu...
# 1                  Adventure Fantasy Action  ...  Adventure Fantasy Action ocean drug abuse exot...
# 2                    Action Adventure Crime  ...  Action Adventure Crime spy based on novel secr...
# 3               Action Crime Drama Thriller  ...  Action Crime Drama Thriller dc comics crime fi...
# 4          Action Adventure Science Fiction  ...  Action Adventure Science Fiction based on nove...
#
# [5 rows x 5 columns]

# %%
df.tail()
# Out:
#                               genres  ...                                           combined
# 4382                           Drama  ...  Drama gang audition police fake homeless actre...
# 4383  Science Fiction Drama Thriller  ...  Science Fiction Drama Thriller distrust garage...
# 4384           Action Crime Thriller  ...  Action Crime Thriller united states\u2013mexic...
# 4385   Comedy Drama Romance TV Movie  ...  Comedy Drama Romance TV Movie date love at fir...
# 4386                     Documentary  ...  Documentary obsession camcorder crush dream gi...
#
# [5 rows x 5 columns]

# %%
data = df[['title', 'combined']]

# %%
data.head()
# Out:
#                                       title                                           combined
# 0                                    Avatar  Action Adventure Fantasy Science Fiction cultu...
# 1  Pirates of the Caribbean: At World's End  Adventure Fantasy Action ocean drug abuse exot...
# 2                                   Spectre  Action Adventure Crime spy based on novel secr...
# 3                     The Dark Knight Rises  Action Crime Drama Thriller dc comics crime fi...
# 4                               John Carter  Action Adventure Science Fiction based on nove...

# %%
data.shape
# Out:
# (4387, 2)

# %%
combined_text = " ".join(df['combined'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(combined_text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Movie content')
plt.show()

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def preprocess_text(text):
  text = re.sub(r"[^a-zA-Z\s]","",text)
  text = text.lower()
  tokens = word_tokenize(text)
  filtered_tokens = [word for word in tokens if word not in stop_words]
  return " ".join(filtered_tokens)

# %%
df['cleaned_text']=df['combined'].apply(preprocess_text)
df.head()
# Out:
#                                      genres  ...                                       cleaned_text
# 0  Action Adventure Fantasy Science Fiction  ...  action adventure fantasy science fiction cultu...
# 1                  Adventure Fantasy Action  ...  adventure fantasy action ocean drug abuse exot...
# 2                    Action Adventure Crime  ...  action adventure crime spy based novel secret ...
# 3               Action Crime Drama Thriller  ...  action crime drama thriller dc comics crime fi...
# 4          Action Adventure Science Fiction  ...  action adventure science fiction based novel m...
#
# [5 rows x 6 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
tfidf_matrix = tfidf_vectorizer.fit_transform(df['cleaned_text'])

# %%
cosine_sim=cosine_similarity(tfidf_matrix,tfidf_matrix)

# %%
print(cosine_sim[1])
# Out:
# [0.02901396 1.         0.03100093 ... 0.01749756 0.02801405 0.        ]

# %%
def recommend_movies(movie_name, cosine_sim=cosine_sim,df=df,top_n=5):
  idx = df[df['title'].str.lower()==movie_name.lower()].index
  if len(idx)==0:
    return "Movie not found in the dataset!"
  idx = idx[0]

  sim_scores = list(enumerate(cosine_sim[idx]))
  sim_scores = sorted(sim_scores,key=lambda x:x[1],reverse=True)
  sim_scores = sim_scores[1:top_n+1]

  movie_indices = [i[0] for i in sim_scores]

  return df[['title']].iloc[movie_indices]

# %%
df['title']
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4382                                        Bang
# 4383                                      Primer
# 4384                                 El Mariachi
# 4385                   Signed, Sealed, Delivered
# 4386                           My Date with Drew
# Name: title, Length: 4387, dtype: object

# %%
# row_index = df[df['title'] == "Avengers: Age of Ultron"].index
row_index = df[df['title'] == "Batman v Superman: Dawn of Justice"].index
print(row_index)
# Out:
# Index([9], dtype='int64')

# %%
movie_name = data['title'][9]
print(movie_name)
# Out:
# Batman v Superman: Dawn of Justice

# %%
# Example Recommendation
print(f"Recommendations for the Movie {movie_name}")
recommendations = recommend_movies(movie_name)
print(recommendations)
# Out:
# Recommendations for the Movie Batman v Superman: Dawn of Justice
#                 title
# 14       Man of Steel
# 861       Superman II
# 424    Batman Returns
# 1401  Superhero Movie
# 3590         Defendor
